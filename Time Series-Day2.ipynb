# %%
import pandas as pd
from datetime import datetime
import pandas_datareader as pdr

# %%
df_tesla=pdr.get_data_yahoo('TSLA')

# %%
df_tesla
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-06-26   77.389999   74.620003   77.337997   75.498001  33020500.0
# 2017-06-27   75.279999   72.403999   75.279999   72.473999  34982000.0
# 2017-06-28   74.348000   72.503998   73.335999   74.248001  31512500.0
# 2017-06-29   74.199997   70.820000   74.122002   72.150002  41105000.0
# 2017-06-30   73.353996   71.924004   72.741997   72.321999  29242500.0
# ...                ...         ...         ...         ...         ...
# 2022-06-16  675.500000  626.080017  668.210022  639.299988  35796900.0
# 2022-06-17  662.909973  639.590027  640.299988  650.280029  30810900.0
# 2022-06-21  730.729980  673.000000  673.809998  711.109985  40931000.0
# 2022-06-22  740.500000  701.479980  703.510010  708.260010  33702500.0
# 2022-06-23  717.950012  685.909973  713.715027  701.409973  30060323.0
#
#              Adj Close
# Date
# 2017-06-26   75.498001
# 2017-06-27   72.473999
# 2017-06-28   74.248001
# ...

# %%
#Simple moving average
df_tesla['Open'].plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['Open:10 days rolling']=df_tesla['Open'].rolling(window=10,min_periods=1).mean()

# %%
#Min_periods=1 karne se sirf first element hi NaN aayega
#Jabki pehle 9 elements NaN aana chahiye(As window=10)
df_tesla[['Open','Open:10 days rolling']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla[['Open','Open:10 days rolling']].plot(xlim=['2020-01-01','2021-01-01'],figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#Note,we passed the data,in the form of a list

# %% [markdown]
# #We use this simple moving average,to know,when to buy or sell the stocks,eg ehrn the Blue line is higher than orange,hold it,and sell when blue line intersects and goes below orange line

# %%
df_tesla['Open:30 days rolling']=df_tesla['Open'].rolling(window=30,min_periods=1).mean()
df_tesla[['Open','Open:30 days rolling']].plot(xlim=['2020-01-01','2021-01-01'],figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['Open:50 days rolling']=df_tesla['Open'].rolling(window=50,min_periods=1).mean()
df_tesla[['Open','Open:10 days rolling','Open:30 days rolling','Open:50 days rolling']].plot(xlim=['2020-01-01','2021-01-01'],figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
##Expanding
##Cumulative Moving Average

df_tesla['Open'].expanding().mean().plot(figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ##Exponential Weighted Moving Average
